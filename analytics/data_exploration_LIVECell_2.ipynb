# %% [markdown]
# # Data Exploration of LIVECell - Segmentation and BBOX Label Meaning
#
# Reference code: [COCO image viewer](https://github.com/Tony607/labelme2coco/blob/master/COCO_Image_Viewer.ipynb)

# %%
import pathlib2
import pandas as pd
import numpy as np
import json
import random
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw
import re

# %%
# Helper functions

# Load the dataset json
class LiveCellDataset:
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['limegreen','blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink',
                       'gold', 'orchid', 'slateblue', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        with open(self.annotation_path) as json_file:
            self.livecell = json.load(json_file)

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', str],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False, verbose=False):
        """
        display the image and the corresponding annotations according to the given image_id or the one at random
        :param image_id: str image id given or at random
        :param show_polys: boolean flag if polygons should be visualized
        :param show_bbox: boolean flag if bounding box should be visualized
        :param show_crowds: boolean flag if the crowd (a cloud of objects) should be visualized
        :param use_url: boolean flag if url should be leveraged
        :param verbose: boolean flag if the additional information should be shown in the terminal
        :return:
        """
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image through url
        if use_url:
            image_path = image['url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))
            if verbose:
                print("It successfully opens the image via url.")
        # Open the image through the local path
        else:
            # filtering for the cell type dir is necessary due to the additional dir structure for cell type
            # image_path = "{}/{}".format(self.image_dir, image['file_name'])
            filtered_dir_obj = re.match(r"[a-zA-Z0-9]+", image['file_name'], flags=0)
            filtered_dir = filtered_dir_obj.group(0)
            image_path = self.image_dir / filtered_dir / image['file_name']
            image = PILImage.open(image_path.as_posix())
            if verbose:
                print("It successfully opens the image via local path.")

        # Calculate the size and adjusted display size with aspect ratio being the same
        max_width = 704
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        # Print the annotation info for the specific image id
        print('  segmentations ({}),'.format(
            len(self.segmentations[image_id])))
        current_img_one_annot = self.segmentations[image_id][0]
        print('  and details for image_id {}:'.format(current_img_one_annot['image_id']))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE (not adapted presently!)
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add one polygon for an object
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int) # return np.array([[...]]) (1*m)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            # the following snippet for traversing the self.colors list is unnecessary since there is only one kind
            # of segmentation label for each image
            # if i < len(self.colors):
            #     poly_colors[segm['id']] = self.colors[i]
            # else:
            #     poly_colors[segm['id']] = 'white'
            poly_colors[segm['id']] = self.colors[0]
            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            if verbose:
                print('    {}:{}:{}'.format(
                    segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.livecell.get('info')

    def process_licenses(self):
        self.licenses = self.livecell.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.livecell['categories']:
            cat_id = category['id']
            super_category = category['supercategory']
            cat_name = category['name']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        # create the dict with key (str): image_id and value (dict): each row of key-value pairs of image metadata
        self.images = {}
        for image in self.livecell['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        # create the dict with key (str): image_id and value (list): list of annotation metadata (dict)
        self.segmentations = {}
        for segmentation in self.livecell['annotations'].values():
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %% [markdown]
# ## Define relevant paths

# %%
current_dir = pathlib2.Path.cwd()
# current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
print("currentdir: ", current_dir.as_posix())
project_dir = current_dir.parent
print("project dir: ", project_dir.as_posix())
# Out:
# currentdir:  F:/Kaggle/sartorius_cell_instance_segmentation/code/rkx_cell_is/analytics
# project dir:  F:/Kaggle/sartorius_cell_instance_segmentation/code/rkx_cell_is

# %%
ds_path = project_dir / 'dataset'
print("dataset dir: ", ds_path.as_posix())
livecell_ds_path = ds_path / 'LIVECell_dataset_2021'
print("livecell dataset dir: ", livecell_ds_path.as_posix())
livecell_ds_annot_path, livecell_ds_imgs_path = [x for x in livecell_ds_path.iterdir() if x.is_dir()]

livecell_train_meta_path = livecell_ds_annot_path / 'LIVECell' / 'livecell_coco_train.json'
livecell_val_meta_path = livecell_ds_annot_path / 'LIVECell' / 'livecell_coco_val.json'
livecell_test_meta_path = livecell_ds_annot_path / 'LIVECell' / 'livecell_coco_test.json'

livecell_train_val_img_path = livecell_ds_imgs_path / 'livecell_train_val_images'
livecell_test_img_path = livecell_ds_imgs_path / 'livecell_test_images'
# Out:
# dataset dir:  F:/Kaggle/sartorius_cell_instance_segmentation/code/rkx_cell_is/dataset
# livecell dataset dir:  F:/Kaggle/sartorius_cell_instance_segmentation/code/rkx_cell_is/dataset/LIVECell_dataset_2021

# %%
# Display fundamental descriptions

livecell_ds = LiveCellDataset(livecell_test_meta_path, livecell_test_img_path)
livecell_ds.display_info()
livecell_ds.display_licenses()
livecell_ds.display_categories()
# Out:
# Dataset Info:
# =============
#   year: 2020
#   version: 1.0
#   description: LIVECell 2021 Dataset
#   contributor: Sartorius
#   url: https://osf.io/6kang/?view_only=da0516e9189b4dbdbf018475113ed343
#   date_created: 2021/01/19
#
# Licenses:
# =========
#   id: 1
#   name: Attribution-NonCommercial 4.0 International License
#   url: https://creativecommons.org/licenses/by-nc/4.0/
#
#
# Categories:
# =========
#   super_category: cell
#     id 1: cell

# %% [markdown]
# ## Draw segmentation label (Polygons) and/or bounding box label on the corresponding image

# %%
# Draw the annotations on the image in the test dataset
# TODO: draw the polygons based on the results from the notebook data_exploration_LIVECell.ipynb

test_img_annot_html = livecell_ds.display_image('random', show_polys=True, show_bbox=False, show_crowds=False, use_url=False, verbose=True)
# Out:
# Image:
# ======
#   id: 1007545
#   width: 704
#   height: 520
#   file_name: BV2_Phase_A4_1_02d16h00m_1.tif
#   original_filename: BV2_Phase_A4_1_02d16h00m_1.png
#   url: https://darwin.v7labs.com/api/images/870186/original
# It successfully opens the image via local path.
#   segmentations (1130),
#   and details for image_id 1007545:
#     1007546:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007547:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007548:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007549:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007550:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007551:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007552:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007553:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007554:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007555:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007556:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007557:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007558:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007559:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007560:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007561:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007562:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007563:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007564:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007565:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007566:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007567:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007568:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007569:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007570:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007571:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007572:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007573:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007574:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007575:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007576:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007577:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007578:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007579:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007580:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007581:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007582:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007583:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007584:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007585:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007586:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007587:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007588:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007589:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007590:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007591:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007592:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007593:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007594:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007595:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007596:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007597:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007598:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007599:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007600:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007601:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007602:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007603:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007604:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007605:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007606:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007607:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007608:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007609:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007610:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007611:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007612:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007613:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007614:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007615:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007616:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007617:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007618:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007619:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007620:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007621:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007622:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007623:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007624:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007625:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007626:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007627:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007628:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007629:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007630:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007631:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007632:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007633:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007634:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007635:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007636:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007637:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007638:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007639:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007640:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007641:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007642:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007643:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007644:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007645:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007646:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007647:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007648:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007649:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007650:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007651:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007652:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007653:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007654:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007655:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007656:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007657:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007658:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007659:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007660:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007661:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007662:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007663:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007664:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007665:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007666:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007667:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007668:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007669:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007670:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007671:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007672:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007673:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007674:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007675:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007676:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007677:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007678:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007679:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007680:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007681:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007682:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007683:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007684:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007685:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007686:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007687:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007688:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007689:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007690:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007691:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007692:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007693:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007694:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007695:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007696:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007697:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007698:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007699:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007700:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007701:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007702:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007703:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007704:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007705:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007706:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007707:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007708:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007709:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007710:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007711:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007712:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007713:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007714:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007715:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007716:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007717:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007718:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007719:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007720:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007721:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007722:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007723:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007724:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007725:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007726:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007727:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007728:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007729:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007730:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007731:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007732:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007733:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007734:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007735:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007736:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007737:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007738:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007739:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007740:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007741:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007742:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007743:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007744:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007745:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007746:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007747:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007748:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007749:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007750:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007751:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007752:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007753:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007754:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007755:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007756:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007757:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007758:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007759:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007760:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007761:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007762:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007763:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007764:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007765:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007766:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007767:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007768:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007769:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007770:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007771:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007772:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007773:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007774:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007775:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007776:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007777:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007778:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007779:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007780:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007781:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007782:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007783:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007784:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007785:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007786:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007787:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007788:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007789:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007790:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007791:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007792:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007793:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007794:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007795:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007796:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007797:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007798:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007799:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007800:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007801:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007802:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007803:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007804:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007805:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007806:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007807:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007808:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007809:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007810:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007811:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007812:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007813:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007814:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007815:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007816:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007817:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007818:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007819:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007820:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007821:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007822:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007823:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007824:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007825:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007826:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007827:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007828:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007829:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007830:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007831:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007832:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007833:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007834:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007835:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007836:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007837:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007838:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007839:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007840:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007841:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007842:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007843:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007844:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007845:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007846:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007847:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007848:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007849:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007850:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007851:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007852:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007853:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007854:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007855:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007856:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007857:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007858:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007859:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007860:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007861:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007862:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007863:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007864:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007865:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007866:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007867:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007868:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007869:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007870:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007871:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007872:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007873:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007874:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007875:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007876:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007877:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007878:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007879:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007880:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007881:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007882:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007883:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007884:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007885:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007886:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007887:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007888:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007889:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007890:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007891:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007892:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007893:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007894:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007895:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007896:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007897:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007898:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007899:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007900:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007901:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007902:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007903:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007904:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007905:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007906:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007907:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007908:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007909:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007910:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007911:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007912:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007913:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007914:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007915:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007916:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007917:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007918:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007919:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007920:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007921:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007922:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007923:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007924:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007925:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007926:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007927:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007928:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007929:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007930:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007931:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007932:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007933:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007934:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007935:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007936:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007937:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007938:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007939:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007940:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007941:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007942:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007943:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007944:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007945:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007946:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007947:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007948:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007949:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007950:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007951:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007952:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007953:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007954:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007955:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007956:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007957:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007958:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007959:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007960:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007961:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007962:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007963:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007964:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007965:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007966:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007967:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007968:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007969:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007970:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007971:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007972:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007973:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007974:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007975:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007976:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007977:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007978:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007979:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007980:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007981:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007982:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007983:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007984:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007985:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007986:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007987:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007988:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007989:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007990:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007991:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007992:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007993:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007994:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007995:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007996:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007997:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007998:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1007999:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008000:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008001:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008002:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008003:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008004:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008005:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008006:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008007:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008008:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008009:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008010:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008011:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008012:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008013:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008014:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008015:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008016:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008017:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008018:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008019:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008020:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008021:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008022:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008023:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008024:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008025:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008026:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008027:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008028:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008029:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008030:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008031:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008032:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008033:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008034:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008035:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008036:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008037:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008038:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008039:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008040:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008041:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008042:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008043:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008044:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008045:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008046:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008047:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008048:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008049:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008050:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008051:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008052:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008053:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008054:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008055:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008056:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008057:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008058:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008059:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008060:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008062:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008063:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008064:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008065:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008066:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008067:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008068:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008069:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008070:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008071:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008072:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008073:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008074:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008075:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008076:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008077:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008078:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008079:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008080:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008081:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008082:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008083:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008084:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008085:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008086:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008087:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008088:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008089:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008090:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008091:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008092:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008093:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008094:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008095:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008096:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008097:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008098:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008099:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008100:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008101:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008102:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008103:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008104:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008105:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008106:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008107:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008108:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008109:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008110:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008111:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008112:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008113:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008114:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008115:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008116:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008117:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008118:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008119:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008120:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008121:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008122:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008123:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008124:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008125:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008126:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008127:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008128:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008129:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008130:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008131:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008132:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008133:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008134:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008135:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008136:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008137:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008138:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008139:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008140:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008141:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008142:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008143:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008144:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008145:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008146:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008147:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008148:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008149:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008150:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008151:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008152:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008153:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008154:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008155:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008156:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008157:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008158:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008159:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008160:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008161:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008162:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008163:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008164:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008165:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008166:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008167:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008168:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008169:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008170:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008171:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008172:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008173:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008174:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008175:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008176:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008177:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008178:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008179:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008180:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008181:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008182:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008183:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008184:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008185:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008186:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008187:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008188:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008189:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008190:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008191:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008192:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008193:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008194:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008195:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008196:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008197:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008198:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008199:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
# ...
#     1008463:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008464:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008465:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008466:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008467:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008469:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008470:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008471:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008472:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008473:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008474:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008475:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008476:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008477:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008478:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008479:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008480:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008481:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008482:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008483:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008484:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008485:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008486:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008487:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008488:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008489:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008490:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008491:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008492:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008493:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008494:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008495:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008496:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008497:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008498:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008500:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008501:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008502:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008503:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008504:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008505:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008506:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008507:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008508:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008509:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008510:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008511:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008512:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008513:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008514:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008515:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008516:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008517:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008518:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008520:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008521:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008522:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008523:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008524:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008525:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008526:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008527:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008528:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008529:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008530:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008531:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008532:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008533:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008534:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008535:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008536:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008537:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008538:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008539:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008540:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008541:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008542:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008543:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008544:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008545:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008546:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008547:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008550:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008552:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008553:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008554:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008556:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008557:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008558:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008559:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008560:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008561:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008562:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008563:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008564:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008565:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008566:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008567:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008568:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008569:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008570:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008572:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008573:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008574:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008575:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008576:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008577:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008578:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008579:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008580:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008581:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008582:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008583:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008584:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008585:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008586:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008587:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008588:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008589:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008590:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008591:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008592:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008593:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008594:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008595:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008597:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008598:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008599:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008600:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008601:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008602:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008603:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008604:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008605:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008606:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008607:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008608:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008609:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008610:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008611:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008612:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008613:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008614:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008615:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008616:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008617:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008618:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008619:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008620:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008621:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008622:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008623:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008625:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008626:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008627:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008628:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008629:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008630:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008631:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008632:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008633:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008634:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008635:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008636:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008637:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008638:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008639:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008640:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008641:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008642:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008643:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008644:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008645:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008646:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008647:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008648:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008649:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008650:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008651:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008652:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008653:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008654:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008655:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008656:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008658:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008659:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008660:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008661:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008662:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008663:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008664:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008665:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008666:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008667:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008668:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008669:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008670:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008671:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008672:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008674:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008675:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008676:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008677:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008678:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008679:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008680:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008681:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008682:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008683:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008684:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008685:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008686:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008687:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008688:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008689:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008690:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008691:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008692:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}
#     1008694:limegreen:{'supercategory': 'cell', 'id': 1, 'name': 'cell'}

# %%
import IPython
IPython.display.HTML(test_img_annot_html)
# Out:
# <div class="container" style="position:relative;"><img src="F:\Kaggle\sartorius_cell_instance_segmentation\code\rkx_cell_is\dataset\LIVECell_dataset_2021\images\livecell_test_images\BV2\BV2_Phase_A4_1_02d16h00m_1.tif" style="position:relative;top:0px;left:0px;width:704px;"><div class="svgclass"><svg width="704" height="520.0"><polygon points="174 494 174 496 175 500 177 501 179 504 181 505 187 505 189 503 190 503
#  191 499 190 497 191 495 190 492 188 490 185 488 179 488 177 489 176 491
#  175 493" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="575 206 575 209 575 211 575 213 576 214 577 215 578 215 579 215 582 215
#  587 214 590 215 590 213 589 211 588 209 586 207 585 205 583 204 581 203
#  579 204 577 204 576 205" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="209 510 213 510 214 511 218 513 222 514 223 514 223 520 205 519 205 513
#  205 512 206 511 207 511" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="263 455 261 456 260 457 260 459 260 462 261 464 262 466 264 466 265 466
#  266 466 268 467 270 467 271 467 272 467 274 466 273 460 273 459 272 457
#  270 456 269 456" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="609 238 612 238 613 237 615 236 616 234 617 231 617 228 616 226 615 224
#  606 224 604 224 603 224 602 225 601 226 602 228 603 228 604 231 607 234
#  608 237 608 238 608 237" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="333 499 336 499 339 499 341 500 342 502 342 505 343 512 342 513 341 514
#  339 515 337 514 335 514 335 510 334 508 333 506 332 505 331 503 331 502
#  332 501" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 23 343  23 349  24 350  25 351  26 351  26 352  27 352  30 353  32 354
#   34 354  36 353  37 352  38 352  39 350  40 347  40 344  39 342  38 340
#   37 339  28 338  27 339  25 341  24 342" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 21 284  26 284  28 285  31 285  33 287  35 288  36 291  36 294  36 296
#   35 299  34 300  32 301  29 300  27 300  24 298  22 297  21 294  21 291
#   20 290  20 288  20 286" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="538 224 542 224 544 226 546 228 547 231 547 233 546 233 545 234 544 236
#  542 237 540 237 538 237 536 237 535 234 534 231 534 228 535 226 536 225" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 43 482  46 482  50 483  52 485  54 487  54 487  56 489  56 491  56 493
#   56 494  54 495  52 495  52 497  52 498  52 500  51 500  50 500  43 499
#   42 498  42 498  42 498  40 496  39 495  37 494  37 494  37 492  37 489
#   38 487  39 486  40 485  41 484  42 483" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="166 484 165 487 165 489 167 492 169 493 170 494 172 495 174 495 174 494
#  175 493 176 491 177 489 178 489 177 488 175 486 173 484 172 482 169 482
#  168 482 167 483" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 91 507  97 507  99 508 100 509 101 512 100 514  99 515  98 516  97 518
#   97 520  90 519  90 517  90 515  89 512  88 511  89 510  89 509  90 508" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 13 500  16 500  19 501  20 502  20 508  20 510  20 511  18 512  17 513
#   15 514  14 514  13 513  12 511  11 510  11 508  11 505   9 504  10 503
#   11 502  12 501  13 501" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 28 490  32 489  33 490  34 490  35 491  37 491  37 492  37 494  37 496
#   36 498  35 500  33 501  30 501  29 501  28 500  25 499  25 498  24 497
#   24 493  25 492  26 490  28 490" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="101 509 103 509 104 514 105 515 107 516 106 519  97 520  97 518  98 516
#   99 515 100 513 101 512 101 510" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="126 414 131 414 133 415 135 416 136 417 137 419 138 422 138 424 138 426
#  137 428 136 429 134 429 132 429 129 428 126 427 125 426 124 424 124 422
#  124 420 124 418 124 416 124 415" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="655 127 656 126 660 126 661 126 663 127 664 128 665 130 665 132 666 134
#  666 137 664 138 664 139 659 139 658 138 657 138 655 136 653 137 653 127
#  654 127 655 127" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points=" 43 396  46 396  48 397  50 398  51 398  52 399  52 401  51 402  50 403
#   50 412  49 412  47 413  44 413  42 412  40 410  39 409  38 407  38 401
#   40 398  42 397" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="450 439 450 443 452 445 453 446 455 447 458 447 460 446 461 445 462 443
#  462 436 462 435 460 434 458 434 456 435 455 435 453 436 451 437" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="260 421 265 421 268 421 270 421 272 422 273 422 274 425 274 427 275 430
#  274 432 273 434 271 436 269 436 264 436 262 435 260 433 259 432 260 427
#  260 423" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="302 475 306 474 307 475 309 475 312 477 314 478 315 481 314 483 314 485
#  314 486 313 486 301 487 300 486 299 484 299 480 299 477 300 476 301 475" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="149 491 153 491 156 492 159 493 161 495 162 496 162 503 162 505 159 507
#  157 508 151 508 150 506 147 504 146 503 145 496 146 494 147 493 148 492" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="406 494 409 495 411 496 412 496 413 497 414 502 413 504 412 506 411 507
#  410 509 409 511 407 511 405 510 404 510 402 508 402 507 400 504 399 503
#  399 501 399 499 400 497 402 496 403 495 404 495 405 494" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="605 245 610 245 612 246 613 246 614 247 615 248 616 249 616 257 615 258
#  614 260 613 260 607 260 606 259 605 257 604 256 603 254 602 251 602 248
#  603 247 604 246" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="393 501 397 502 399 503 400 504 401 505 401 506 402 507 402 511 401 512
#  400 512 398 512 397 512 396 514 396 515 395 516 393 516 392 516 390 515
#  388 514 389 505 390 504 391 503 392 502" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="616 152 616 156 616 158 617 159 617 160 618 161 620 162 621 163 623 163
#  626 163 628 162 630 161 631 160 632 160 631 151 631 150 630 149 629 149
#  626 148 625 148 621 148 619 149 618 149 617 150" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="519 212 527 212 529 214 531 215 532 217 533 220 533 222 533 225 532 226
#  531 227 529 227 527 226 525 225 524 224 519 224 518 224 516 224 515 223
#  515 219 515 216 515 215 517 214 518 213" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="533 514 533 520 543 520 543 519 543 518 542 516 541 514 539 513 534 513" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="330 173 332 173 333 175 335 177 336 179 336 181 336 184 335 185 334 186
#  333 186 331 186 329 186 327 185 325 184 322 184 322 177 322 177 324 177
#  325 176 327 175 328 173 328 173" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="425 520 417 520 417 515 419 515 420 514 422 513 423 512 424 512 425 514
#  425 515 426 516 427 520" style="fill:limegreen; stroke:limegreen; stroke-width:1; fill-opacity:0.5" /><polygon points="596 227 599 227 60
